# %%
calificacion=float(input("Ingrese su calificacion: "))
conducta=float(input("Ingrese su conducta"))


if calificacion >=10:
    print("A+")
    if conducta >=10:
        print("tu conducta es excelente")
elif calificacion >=9:
    print("A")
    if conducta >=9:
            print("buena")
elif calificacion >=8:
    print("B")
    if conducta >=8:
            print("regular")
elif calificacion >=7:
    print("C")
    if conducta >=7:
            print("mala")
# Out:
# B
# regular

# %% [markdown]
# OPERADORES LOGICOS

# %%
PL1 = False
PL2 = True
print(PL1 or PL2)
# Out:
# True

# %%
edad=65
tipo="Adulto mayor"
es_mayor=edad >=18
print(es_mayor)
aplica_descuento =(edad>=60) and (tipo >="adulto_mayor")
print(aplica_descuento)
# Out:
# True
# False

# %%
edad=int(input("Ingresetu edad"))
if not (edad < 0 ):
    print("Aguanta, no hay edades menores a cero")
else:
    print("Ahora si vamos a trabajar con edades reales")
# Out:
# Aguanta, no hay edades menores a cero

# %%
precio = 45

tipo = input("Ingrese su tipo: ")
if tipo == "adulto_mayor":
    descuento = precio * 0.12
elif tipo == "profesor" or tipo =="estudiante":
    descuento=precio*0.10
else : descuento=0
total = precio-descuento
print (f"total a pagar: ${total:2f}")
# Out:
# total a pagar: $39.600000

# %%
edad=16
if edad >=18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres menor de edad

# %% [markdown]
# ### Ejercicio 2: Número par o impar
# **Enunciado:** Crea un programa que pida un número entero y determine si es par o impar usando el operador módulo `%`.
# **Entrada:** `7`
# **Salida:** `7 es un número impar`

# %%
numero=int(input("Ingresa un numero entero"))
if (numero % 2 ==0):
    print("es un numero par")
else:
    print("es un  numero impar")
# Out:
# es un  numero impar

# %% [markdown]
# Ejercicio 3: calificacion aprobatoria
# Enunciado: crea u programa que pida una calificacion de 0 a 10 y muestre si la materia esta aprobada (mayor o igual a 6) o reprobada
# ENTRADA: 7 SALIDA. APROBADO

# %%
calificacion=int(input("Ingresa un calificacion entero"))
if calificacion >= 6:
     print("aprobada")
if calificacion <=5:
     print("reprobado")
# Out:
# reprobado

# %% [markdown]
# Ejercicio 4: Clasificacion por rango de edad con elif
# enunciado: crea un programa que clasifique a una persona segun su edad menor de 3 años "bebe" de 3 a 12 "niño" de 13 a 17 "adolecente" y de 18 en adelenate "adulto". usa elif
# ENTRADA:15 SALIDA: ADOLECENTE

# %%
edad = int(input("Ingrese la edad: "))

if edad < 3:
    print("bebe")
elif edad <= 12:
    print("niño")
elif edad <= 17:
    print("adolecente")
else:
    print("adulto")
# Out:
# adolecente

# %% [markdown]
# Ejercicio 5: Descuento por tipo de visitante
# **Enunciado:** Crea un programa que pida el tipo de visitante (`adulto_mayor`,
# `profesor`, `estudiante` u `otro`) y calcule el precio de un boleto base de $45
# aplicando solo un descuento: adulto mayor 12%, profesor 10%, estudiante 10%, otro
# 0%.
# **Entrada:** `estudiante`
# **Salida:** `Precio final: $40.50`

# %%
precio = 45

tipo = input("Ingrese su tipo: ")
if tipo == "adulto_mayor":
    descuento = precio * 0.12
elif tipo == "profesor" or tipo =="estudiante":
    descuento=precio*0.10
else : descuento=0
total = precio-descuento
print (f"total a pagar: ${total:2f}")

# %% [markdown]
# ### Ejercicio 6: Acceso con operador and
# **Enunciado:** Crea un programa que pida la edad y si la persona tiene credencial vigente (`si`/`no`). Solo se permite el acceso si la edad es mayor o igual a 18 y la credencial es `si`.
# **Entrada:** `20` y `si`
# **Salida:** `Acceso permitido`

# %%
edad = int(input("ingrese su edad :"))
credencial = input("Tiene credencial vigente:")
if edad >=18 and credencial == "si":
    print("Acceso permitido")
# Out:
# Acceso permitido

# %% [markdown]
# ### Ejercicio 7: Detección de número negativo con or
# **Enunciado:** Crea un programa que pida dos números y muestre una alerta si alguno de ellos es negativo, usando el operador `or`.
# **Entrada:** `5` y `-3`
# **Salida:** `Hay un número negativo`

# %%
numero1 = int(input("Ingrese un numero:"))
numero2 = int(input("Ingrese otro numero:"))
if numero1 < 0 or numero2 < 0:
    print("Hay un numero negativo")
# Out:
# Hay un numero negativo

# %% [markdown]
# ### Ejercicio 8: Positivo y par con anidamiento
# **Enunciado:** Crea un programa que pida un número entero y, si es positivo, verifique además si es par usando un `if` anidado.
# **Entrada:** `8`
# **Salida:** `El número es positivo y par`

# %%
numero = int(input("Ingrese un numero:"))
if numero > 0:
 if numero % 2 == 0:
    print("El numero es positivo y par")
else:
    print("El numero es positivo e impar")
# Out:
# El numero es positivo y par

# %% [markdown]
# ### Ejercicio 9: Salir del proceso con not
# **Enunciado:** Crea un programa que pregunte si desea continuar. Si la respuesta NO es `si` (usa el operador `not`), el proceso finaliza.
# **Entrada:** `no`
# **Salida:** `Proceso finalizado`

# %%
proceso = input("Desea continuar con el proceso? (si/no):")
if not (proceso == "si"):
    print("proceso finalizado")
# Out:
# proceso finalizado

# %% [markdown]
# BLOQUE 2 · TEMA 6: ESTRUCTURA DE REPETICIÓN - WHILE (contadores, acumuladores, break y continue)

# %%
contador = 1
while contador <= 5:
    print(f"precio por persona {contador}")
    contador += 1
# Out:
# el contador vale 1
# el contador vale 2
# el contador vale 3
# el contador vale 4
# el contador vale 5

# %% [markdown]
# Ejercicio 11: Suma de los primeros N números
# **Enunciado:** Crea un programa que pida un número entero positivo N y calcule con `while` la suma de los números del 1 al N.
# **Entrada:** `5`
# **Salida:** `La suma del 1 al 5 es: 15`

# %% [markdown]
# Ejercicio 12: Tabla de multiplicar con while
# **Enunciado:** Crea un programa que pida un número y muestre su tabla de multiplicar del 1 al 10 usando `while`.
# **Entrada:** `3`
# **Salida:**

# %%
tabla = int(input("Ingrese un numero para la tabla de multiplicar: "))
for n in range(1, 10):
    resultado = tabla * n
    print(f"{tabla} x {n} = {resultado}")
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27

# %% [markdown]
# Ejercicio 13: Cuenta regresiva
# **Enunciado:** Crea un programa que imprima los números del 5 al 1 con `while` y después el mensaje "Despegue".
# **Entrada:** Ninguna.

# %%
contador = 1
while contador <= 5:
    print(f"{contador}")
    contador += 1
print ("despegue")
# Out:
# 1
# 2
# 3
# 4
# 5
# despegue

# %% [markdown]
# Salir del ciclo con break
# **Enunciado:** Crea un programa que capture textos con `input()` dentro de un `while True`. Si el usuario escribe `salir`, el ciclo se interrumpe con `break`.
# **Entrada:** `hola`, `mundo`, `salir`
# **Salida:**

# %%
while True:
    texto= input("ingrese texto: ")
    if texto == "salir":
        print("fin del ciclo")
        break
    print("el texto ingresadado es: ", texto)
# Out:
# el texto ingresadado es:  hola
# fin del ciclo

# %% [markdown]
# Ejercicio 15: Promedio con acumulador
# **Enunciado:** Crea un programa que capture calificaciones hasta que el usuario escriba `fin` y calcule el promedio con un acumulador y un contador.
# **Entrada:** `8`, `9`, `10`, `fin`
# **Salida:** `El promedio es: 9.0`

# %%
suma = 0
contador = 0
while True:
    entrada = input("Ingresa una calificación: ")
    
    if entrada == "fin":
        break
        
    calificacion = float(entrada)
    suma += calificacion
    contador += 1

if contador > 0:
    promedio = suma / contador
    print(f"El promedio es: {promedio}")
# Out:
# El promedio es: 5.666666666666667

# %% [markdown]
# Ejercicio 16: Validación de contraseña
# **Enunciado:** Crea un programa que pida una contraseña repetidamente hasta que el usuario escriba la contraseña correcta `secreto`, momento en el que se muestra "Acceso concedido".
# **Entrada:** `1234`, `abcd`, `secreto`
# **Salida:** `Acceso concedido`

# %%
while True:
    palabra = input("Ingresa una palabra: ")
    if palabra == "secreto":
        print("ACCESO CONCEDIDO")
        break
# Out:
# ACCESO CONCEDIDO
