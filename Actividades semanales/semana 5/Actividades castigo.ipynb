# %% [markdown]
# Desafío Extra 1: Lista de espera con tuplas
# Crea una tupla `espera = ("María", "José", "Carlos", "Lucía", "Pedro")`. Imprime el tercer elemento, captura dos nombres nuevos con `input()`, anéxalos en una nueva
# tupla, conviértela en lista, ordénala alfabéticamente y muestra la cantidad total
# de personas.

# %%
#tupla

espera = ("Maria", "Jose", "Carlos", "Lucia", "Pedro")

print(espera[2])

nombre1 = input("Ingresa un nombre: ")
nombre2 = input("Ingresa otro nombre: ")

espera2 = ("Maria", "Jose", "Carlos", "Lucia", "Pedro", nombre1, nombre2)

lista = list(espera2)

lista.sort()

print("Personas ordenadas en orden alfabetico:", lista)

print(len(espera2))
# Out:
# Carlos
# Personas ordenadas en orden alfabetico: ['Carlos', 'Jose', 'Lucia', 'Maria', 'Pedro', 'itzel', 'vania']
# 7

# %% [markdown]
# Desafío Extra 2: Contador de votos con diccionario
# Crea un diccionario `votos = {"Rojo": 0, "Azul": 0, "Verde": 0}`. Pide al usuario
# el color de su voto cinco veces, suma uno al valor correspondiente en cada ocasión
# y, al final, imprime con `items()` el color ganador junto con su total.

# %%
votos = {
    "rojo": 0,
    "azul": 0 ,
    "verde": 0,
}

for i in range (5): 
    color = input ("Ingrese color del voto: ")
    if color in votos:
        votos [color] += 1
    else: 
        print ("COLOR INVALIDO!!")

ganador = ()
votos2 = -1

for color, total in votos.items():
    if total > votos2:
        votos2 = total 
        ganador = color 

print (f"el ganador fue {ganador}!! y tiene {votos2} votos!!")
# Out:
# COLOR INVALIDO!!
# el ganador es rojo!! y cuenta con un total de 4 votos!!

# %% [markdown]
# Desafío Extra 3: Validación robusta de entrada
# Escribe un programa que pida al usuario dos números enteros dentro de un bloque
# `try-except`. Si el usuario ingresa texto o un valor vacío, muestra un mensaje
# controlado y repite la solicitud con un ciclo `while`. Luego pide la división del
# primero entre el segundo, con un bloque específico para `ZeroDivisionError`.

# %%
while True:
    try:
        numero1 = int(input("ingrese el primer numero: "))
        numero2 = int(input("ingrese el segundo numero: "))

        print (numero1)
        print (numero2)

        resultado = numero1 / numero2

        print(resultado)
        break

    except ValueError:
        print("INVALIDO!!! ingrese un numero entero \n")

    except ZeroDivisionError:
        print("INVALIDO!!! no se puede divir entre cero\n")

# %% [markdown]
# Desafío Extra 4: Analizador de textos
# Crea un programa que reciba una frase, imprima su longitud con `len()`, la
# convierta a mayúsculas, reemplace la palabra "Python" por "programación" y muestre
# cuántas palabras contiene usando una función que retorne el conteo.

# %%
def palabra(texto):
    return len(texto.split())

frase = input("ingrese una frase, pon hola: ")

print(f"la longitud de la frase es: {len(frase)}")

print(f"la frase en mayusculas es: {frase.upper()}")

reemplazo = frase.replace("hola", "aloha")
print(f"el texto reemplazado es: {reemplazo}")

total = palabra(frase)
print(f"el total de las palabras: {total}")

# %% [markdown]
# Desafío Extra 5: Minimenú modular integrador
# Construye un menú con un ciclo `while` y opciones numéricas que permita ejecutar de
# forma modular: (1) mostrar la tupla de números ordenada, (2) buscar un teléfono en
# el diccionario `contactos`, (3) dividir dos números con manejo de
# `ZeroDivisionError` y (4) analizar un mensaje de texto. La opción (5) debe
# finalizar el programa

# %%
numeros = (15, 3, 8, 42, 4)
contactos = {"itzel": "555-1234", "aldo": "555-5678"}

def opcion1():
    print("tupla de los numeros ordenada: ", tuple(sorted(numeros)))

def opcion2():

    nombre = input("ingrese el nombre que desee buscar: ")

    if nombre in contactos:
        print("ingrese el telefono que desee buscar:", contactos[nombre])
    else:
        print("el contacto NO fue encontrado")

def opcion3():
    try:
        a = float(input("ingrese el primer numero para la division: "))
        b = float(input("ingrese el segundo numero para la division: "))

        print("el resultado de la division de ambos numeros es:", a / b)

    except ZeroDivisionError:
        print("ERROR!!! no se puede dividir entre cero, intente de nuevo")

def opcion4():
    texto = input("ingrese el mensaje que desee analizar: ")
    print("el total de los caracteres de la frase es:", len(texto))
    print("el corte de las palabras de la frase es:", len(texto.split()))

opcion = ()

while opcion != "5":
    print("\n1. tupla ordenada")
    print("2. buscar contacto")
    print("3. dividir números")
    print("4. analizar texto")
    print("5. salir")
    
    opcion = input("elige una de las siguientes opciones: ")

    if opcion == "1":
        opcion1()
    elif opcion == "2":
        opcion2()
    elif opcion == "3":
        opcion3()
    elif opcion == "4":
        opcion4()
    elif opcion == "5":
        print("el programa ha sido finalizado!!!")
    else:
        print("opcion incorrecta, intente de nuevo!!")
# Out:
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
# opcion incorrecta, intente de nuevo!!
#
# 1. tupla ordenada
# 2. buscar contacto
# 3. dividir números
# 4. analizar texto
# 5. salir
