# %%
#Tupla
numeros=(10,20,30,40,50)
frutas=("manzana","pera","uva","naranja")
datos=("ricardo",30 , 2.65, True)

print(type(numeros))
print(type(frutas))
print(type(datos))  

lista=[1]
datos2=(5,)

print(type(lista))
print(type(datos2))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'list'>
# <class 'tuple'>

# %%
coordenada=(2,6)

x, y = coordenada

print(f"coordenada en X:{x}")
print(f"coordenada en Y:{y}")
# Out:
# coordenada en X:2
# coordenada en Y:6

# %%
calificaciones=(88,90,100,85)

calif5 = 50
calif6=80

nuevas_calificaciones=calificaciones +(calif5,calif6)
print(calificaciones)
print(nuevas_calificaciones)
# Out:
# (88, 90, 100, 85)
# (88, 90, 100, 85, 50, 80)

# %%
desordenada=(9,2,7,10,0,8,14,22,4)

print(type(desordenada))
print(desordenada)
lista=list(desordenada)
print()
print(type(lista))
print(lista)

lista.sort()
print(lista)
ordenada=tuple(lista)
print()
print(type(ordenada))
print(ordenada)
# Out:
# <class 'tuple'>
# (9, 2, 7, 10, 0, 8, 14, 22, 4)
#
# <class 'list'>
# [9, 2, 7, 10, 0, 8, 14, 22, 4]
# [0, 2, 4, 7, 8, 9, 10, 14, 22]
#
# <class 'tuple'>
# (0, 2, 4, 7, 8, 9, 10, 14, 22)

# %%
def suma_tupla(t):
    total=0
    for e in t:
        total += e
    return total

calorias = (800 ,950 ,700 ,1300 ,800 ,900 , 650)
resultado= suma_tupla(calorias)
print(f"Metiste a tu cuerpo {resultado} calorias , buuuu zorra!!")
# Out:
# Metiste a tu cuerpo 6100 calorias , buuuu zorra!!

# %%
contactos ={
    "ricardo": "155-555-5555",
    "pedro": "155-555-5556",
    "luisa": "155-555-5557", 
}

# %%
contactos ={
    "ricardo": "155-555-5555",
    "pedro": "155-555-5556",
    "luisa": "155-555-5557", 
}

contactos["cris"]= "239319301"
contactos["ricardo"]="1354659452"

print(contactos)

# %%
print(contactos.keys())
print(contactos.values())   
print(contactos.items())
# Out:
# dict_keys(['ricardo', 'pedro', 'luisa', 'cris'])
# dict_values(['1354659452', '155-555-5556', '155-555-5557', '239319301'])
# dict_items([('ricardo', '1354659452'), ('pedro', '155-555-5556'), ('luisa', '155-555-5557'), ('cris', '239319301')])

# %%
print("impresion de llaves")
for n in contactos.keys():
    print(n)    

print("/nimpresion de valores")
for v in contactos.values():
    print(v)



print("/nImpresion completa")
for n ,t in contactos.items():
    print(f"Nombre: {n}, Telefono: {t}")
# Out:
# impresion de llaves
# ricardo
# pedro
# luisa
# cris
# /nimpresion de valores
# 1354659452
# 155-555-5556
# 155-555-5557
# 239319301
# /nImpresion completa
# Nombre: ricardo, Telefono: 1354659452
# Nombre: pedro, Telefono: 155-555-5556
# Nombre: luisa, Telefono: 155-555-5557
# Nombre: cris, Telefono: 239319301

# %%
def buscar_contacto(contactos,nombre):
    return contactos.get(nombre,"No existe el contacto")

nombre= input("Escriba el nombre del contacto que buscas: ")
telefono = buscar_contacto(contactos,nombre)
print(f"Telefono de {nombre}: {telefono}")
# Out:
# Telefono de luisa: 155-555-5557

# %% [markdown]
# excepciones

# %%
try:
    edad = int (input("Ingresa tu edad:"))
    print(f"tu edad es {edad}")
except ValueError:
    print("Error:,debes ingresar solo numeros enteros")

# %%
try:
    dividiendo = int(input("Dame un numero:"))
    divisor = int (input("entre que numero lo dividimos: "))
    resultado = dividiendo / divisor
    print(F"el resultado es: {resultado}")

except zeroDivisionError:
    print("error de division entre cero:")
else:
    print(f"eL resultado es {resultado}")
finally:
    print("Fue un gusto hacer esta division , chido!!")
# Out:
# el resultado es: 3.5
# eL resultado es 3.5
# Fue un gusto hacer esta division , chido!!

# %%
for n , v in contacto.items():
    print(f"nombre: {n} , telfono: {v}")

# %% [markdown]
# ejercicios: extra 2

# %%
candidatos = {
    "A": 0,
    "B": 0 ,
    "C": 0,
}

cantidad = int(input("¿Cuantos votos van a ser"))
conteo = 1

while conteo <= cantidad:
    voto=input(f"Ingresa el voto{conteo} (A, B o C):")
    print (f"Votaste por {voto.upper()}")
    if voto.upper () in candidatos:
        print ("El voto esta dentro de los candidatos")
        candidatos[voto.upper()] += 1
        conteo += 1
    else:
     print("El voto no es valido")

print("/resultados:")
for k, v in candidatos.items():
    print(f"Opcion {k}, votos: {v}")
# Out:
# Votaste por A
# El voto esta dentro de los candidatos
# Votaste por A
# El voto esta dentro de los candidatos
# /resultados:
# Opcion A, votos: 2
# Opcion B, votos: 0
# Opcion C, votos: 0

# %% [markdown]
# EXTRA 1:

# %% [markdown]
# Tercer elemento de una tupla
# **Enunciado:** Dada la tupla `colores = ("rojo", "verde", "azul", "amarillo", "naranja")`, imprime el tercer elemento (índice 2) y el primer elemento (índice 0).
# **Entrada:** `colores = ("rojo", "verde", "azul", "amarillo", "naranja")`
# **Salida:** `El tercer color es: azul` y `El primer color es: rojo`

# %%
#Tupla
colores=("rojo", "verde" , "azul","amarillo")


print(type(colores))

lista=[1]
datos2=(5,)

print(type(lista))
print(type(datos2))
# Out:
# <class 'tuple'>
# <class 'list'>
# <class 'tuple'>
