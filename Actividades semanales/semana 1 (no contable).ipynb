# %%
En este punto, incialice el proyectoen git

# %%
nombre= input ("ingrese nombre:")
edad = input ("ingrese edad:")


           
print ("Hola" , nombre , "tienes" , edad , "años")
# Out:
# Hola itzel tienes 19 años
